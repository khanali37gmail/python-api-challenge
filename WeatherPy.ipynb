# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime




# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = 'metric'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 2 of Set 1 | pizarro
# Processing Record 3 of Set 1 | margaret river
# Processing Record 4 of Set 1 | jaru
# Processing Record 5 of Set 1 | sylt-ost
# Processing Record 6 of Set 1 | kerikeri
# Processing Record 7 of Set 1 | qaqortoq
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | hawaiian paradise park
# Processing Record 10 of Set 1 | pandan
# Processing Record 11 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 12 of Set 1 | alice springs
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | mahanoro
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | ganshui
# Processing Record 18 of Set 1 | adamstown
# Processing Record 19 of Set 1 | atafu village
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | port lincoln
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | saynshand
# Processing Record 24 of Set 1 | lihue
# Processing Record 25 of Set 1 | puerto natales
# Processing Record 26 of Set 1 | marshfield
# Processing Record 27 of Set 1 | brigantine
# Processing Record 28 of Set 1 | sao vicente
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | almeirim
# Processing Record 31 of Set 1 | lauro de freitas
# Processing Record 32 of Set 1 | aasiaat
# Processing Record 33 of Set 1 | whitehorse
# Processing Record 34 of Set 1 | takamaka
# City not found. Skipping...
# Processing Record 35 of Set 1 | nar'yan-mar
# Processing Record 36 of Set 1 | campo formoso
# Processing Record 37 of Set 1 | ryotsu-minato
# Processing Record 38 of Set 1 | bonthe
# Processing Record 39 of Set 1 | bereket
# Processing Record 40 of Set 1 | manokwari
# Processing Record 41 of Set 1 | neryungri
# Processing Record 42 of Set 1 | zouerate
# Processing Record 43 of Set 1 | notodden
# Processing Record 44 of Set 1 | lazaro cardenas
# Processing Record 45 of Set 1 | demidov
# Processing Record 46 of Set 1 | waitangi
# Processing Record 47 of Set 1 | padang
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | fuerte olimpo
# Processing Record 0 of Set 2 | la passe
# Processing Record 1 of Set 2 | hobyo
# Processing Record 2 of Set 2 | grand-lahou
# Processing Record 3 of Set 2 | pontianak
# Processing Record 4 of Set 2 | cabedelo
# Processing Record 5 of Set 2 | ancud
# Processing Record 6 of Set 2 | asikkala
# Processing Record 7 of Set 2 | lubbock
# Processing Record 8 of Set 2 | gamboula
# Processing Record 9 of Set 2 | suluova
# Processing Record 10 of Set 2 | isafjordur
# Processing Record 11 of Set 2 | san martin
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | suva
# Processing Record 14 of Set 2 | lucapa
# Processing Record 15 of Set 2 | kingston
# Processing Record 16 of Set 2 | tual
# Processing Record 17 of Set 2 | longyearbyen
# Processing Record 18 of Set 2 | utrik
# Processing Record 19 of Set 2 | zalari
# Processing Record 20 of Set 2 | nikol'sk
# Processing Record 21 of Set 2 | odda
# Processing Record 22 of Set 2 | medeiros neto
# Processing Record 23 of Set 2 | blackmans bay
# Processing Record 24 of Set 2 | port mathurin
# Processing Record 25 of Set 2 | egilsstadir
# Processing Record 26 of Set 2 | iskushuban
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | el granada
# Processing Record 29 of Set 2 | pisco
# Processing Record 30 of Set 2 | papatowai
# Processing Record 31 of Set 2 | sonsorol village
# City not found. Skipping...
# Processing Record 32 of Set 2 | usinsk
# Processing Record 33 of Set 2 | afaahiti
# Processing Record 34 of Set 2 | semey
# Processing Record 35 of Set 2 | broken hill
# Processing Record 36 of Set 2 | stanley
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | wanning
# Processing Record 39 of Set 2 | kumbo
# Processing Record 40 of Set 2 | bethel
# Processing Record 41 of Set 2 | keflavik
# Processing Record 42 of Set 2 | bondo
# Processing Record 43 of Set 2 | yei
# Processing Record 44 of Set 2 | zaozersk
# Processing Record 45 of Set 2 | wailua homesteads
# Processing Record 46 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | luoyang
# Processing Record 49 of Set 2 | nova vicosa
# Processing Record 0 of Set 3 | roosevelt
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | manicore
# Processing Record 3 of Set 3 | hamilton
# Processing Record 4 of Set 3 | invercargill
# Processing Record 5 of Set 3 | labuan
# Processing Record 6 of Set 3 | tiksi
# Processing Record 7 of Set 3 | ilulissat
# Processing Record 8 of Set 3 | conde
# Processing Record 9 of Set 3 | altamont
# Processing Record 10 of Set 3 | flying fish cove
# Processing Record 11 of Set 3 | udachny
# Processing Record 12 of Set 3 | tegueste
# Processing Record 13 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 14 of Set 3 | muisne
# Processing Record 15 of Set 3 | puan
# Processing Record 16 of Set 3 | west island
# Processing Record 17 of Set 3 | togur
# Processing Record 18 of Set 3 | iskateley
# Processing Record 19 of Set 3 | remire-montjoly
# Processing Record 20 of Set 3 | barkhan
# Processing Record 21 of Set 3 | ar rutbah
# Processing Record 22 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 23 of Set 3 | constantia
# Processing Record 24 of Set 3 | watford city
# Processing Record 25 of Set 3 | moranbah
# Processing Record 26 of Set 3 | tshabong
# Processing Record 27 of Set 3 | sorong
# Processing Record 28 of Set 3 | cidreira
# Processing Record 29 of Set 3 | alofi
# Processing Record 30 of Set 3 | thompson
# Processing Record 31 of Set 3 | bargara
# City not found. Skipping...
# Processing Record 32 of Set 3 | mezhdurechenskiy
# Processing Record 33 of Set 3 | ta`u
# Processing Record 34 of Set 3 | mandsaur
# Processing Record 35 of Set 3 | santyoku
# Processing Record 36 of Set 3 | dudinka
# Processing Record 37 of Set 3 | taltal
# Processing Record 38 of Set 3 | tazacorte
# Processing Record 39 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 3 | khovd
# Processing Record 41 of Set 3 | amga
# Processing Record 42 of Set 3 | zvecan
# Processing Record 43 of Set 3 | marsh harbour
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | bubaque
# Processing Record 46 of Set 3 | kone
# Processing Record 47 of Set 3 | grand falls-windsor
# Processing Record 48 of Set 3 | vilyuysk
# Processing Record 49 of Set 3 | kostomuksha
# Processing Record 0 of Set 4 | vadso
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | guilin
# Processing Record 3 of Set 4 | dryden
# Processing Record 4 of Set 4 | puerto lempira
# Processing Record 5 of Set 4 | taitung city
# Processing Record 6 of Set 4 | gignac
# Processing Record 7 of Set 4 | bhadarwah
# Processing Record 8 of Set 4 | taroa
# Processing Record 9 of Set 4 | arteche
# Processing Record 10 of Set 4 | luderitz
# Processing Record 11 of Set 4 | moires
# Processing Record 12 of Set 4 | sampit
# Processing Record 13 of Set 4 | saipan
# Processing Record 14 of Set 4 | jining
# Processing Record 15 of Set 4 | inhambane
# Processing Record 16 of Set 4 | kuta
# Processing Record 17 of Set 4 | am djarass
# City not found. Skipping...
# Processing Record 18 of Set 4 | international falls
# Processing Record 19 of Set 4 | palmer
# Processing Record 20 of Set 4 | uturoa
# Processing Record 21 of Set 4 | selfoss
# Processing Record 22 of Set 4 | olonkinbyen
# Processing Record 23 of Set 4 | tolanaro
# Processing Record 24 of Set 4 | lerwick
# Processing Record 25 of Set 4 | badger
# Processing Record 26 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 27 of Set 4 | jamestown
# Processing Record 28 of Set 4 | cartagena del chaira
# Processing Record 29 of Set 4 | itoman
# Processing Record 30 of Set 4 | cambridge
# Processing Record 31 of Set 4 | vernon
# Processing Record 32 of Set 4 | mount pearl
# Processing Record 33 of Set 4 | livingston
# Processing Record 34 of Set 4 | okhotsk
# Processing Record 35 of Set 4 | arraial do cabo
# Processing Record 36 of Set 4 | dalandzadgad
# Processing Record 37 of Set 4 | road town
# Processing Record 38 of Set 4 | ketchikan
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | klyuchi
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | boa vista
# Processing Record 43 of Set 4 | puerto aysen
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | belyy yar
# Processing Record 46 of Set 4 | portland
# Processing Record 47 of Set 4 | sao jose da coroa grande
# Processing Record 48 of Set 4 | shenjiamen
# Processing Record 49 of Set 4 | balabac
# Processing Record 0 of Set 5 | weno
# Processing Record 1 of Set 5 | myeik
# Processing Record 2 of Set 5 | enniskillen
# Processing Record 3 of Set 5 | khash
# Processing Record 4 of Set 5 | manadhoo
# Processing Record 5 of Set 5 | sola
# Processing Record 6 of Set 5 | kamyshlov
# Processing Record 7 of Set 5 | lompoc
# Processing Record 8 of Set 5 | hermanus
# Processing Record 9 of Set 5 | hadibu
# Processing Record 10 of Set 5 | hede
# Processing Record 11 of Set 5 | talcahuano
# Processing Record 12 of Set 5 | ust-nera
# Processing Record 13 of Set 5 | tateyama
# Processing Record 14 of Set 5 | hovd
# Processing Record 15 of Set 5 | haiku-pauwela
# Processing Record 16 of Set 5 | nuuk
# Processing Record 17 of Set 5 | prince rupert
# Processing Record 18 of Set 5 | inirida
# Processing Record 19 of Set 5 | birjand
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 22 of Set 5 | howrah
# Processing Record 23 of Set 5 | port-gentil
# Processing Record 24 of Set 5 | mount gambier
# Processing Record 25 of Set 5 | kharp
# Processing Record 26 of Set 5 | mount isa
# Processing Record 27 of Set 5 | lebu
# Processing Record 28 of Set 5 | papao
# Processing Record 29 of Set 5 | boguchany
# Processing Record 30 of Set 5 | happy valley-goose bay
# Processing Record 31 of Set 5 | polignano a mare
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | upata
# Processing Record 34 of Set 5 | lorengau
# Processing Record 35 of Set 5 | wuwei
# Processing Record 36 of Set 5 | saint croix
# Processing Record 37 of Set 5 | alta
# Processing Record 38 of Set 5 | olinda
# Processing Record 39 of Set 5 | dolores
# Processing Record 40 of Set 5 | inarajan village
# Processing Record 41 of Set 5 | ujae
# Processing Record 42 of Set 5 | sodankyla
# Processing Record 43 of Set 5 | esfarayen
# Processing Record 44 of Set 5 | tsiombe
# Processing Record 45 of Set 5 | vilhena
# Processing Record 46 of Set 5 | bilibino
# Processing Record 47 of Set 5 | richards bay
# Processing Record 48 of Set 5 | yuzhno-kurilsk
# Processing Record 49 of Set 5 | vorgashor
# Processing Record 0 of Set 6 | anadyr
# Processing Record 1 of Set 6 | ocean shores
# Processing Record 2 of Set 6 | san antonio de pale
# Processing Record 3 of Set 6 | hotan
# Processing Record 4 of Set 6 | chany
# Processing Record 5 of Set 6 | bara
# Processing Record 6 of Set 6 | holualoa
# Processing Record 7 of Set 6 | vilyuchinsk
# Processing Record 8 of Set 6 | rio grande
# Processing Record 9 of Set 6 | port elizabeth
# Processing Record 10 of Set 6 | tamanrasset
# Processing Record 11 of Set 6 | berezovyy
# Processing Record 12 of Set 6 | camarinas
# Processing Record 13 of Set 6 | el galpon
# Processing Record 14 of Set 6 | neiafu
# Processing Record 15 of Set 6 | kudahuvadhoo
# Processing Record 16 of Set 6 | awjilah
# Processing Record 17 of Set 6 | natchitoches
# Processing Record 18 of Set 6 | galliano
# Processing Record 19 of Set 6 | moncion
# Processing Record 20 of Set 6 | outapi
# City not found. Skipping...
# Processing Record 21 of Set 6 | sungailiat
# Processing Record 22 of Set 6 | najran
# Processing Record 23 of Set 6 | crane
# Processing Record 24 of Set 6 | ola
# Processing Record 25 of Set 6 | santiago de cuba
# Processing Record 26 of Set 6 | ponnani
# Processing Record 27 of Set 6 | georgetown
# Processing Record 28 of Set 6 | nemuro
# Processing Record 29 of Set 6 | east london
# Processing Record 30 of Set 6 | anyksciai
# Processing Record 31 of Set 6 | greymouth
# Processing Record 32 of Set 6 | harper
# Processing Record 33 of Set 6 | staryye ozinki
# Processing Record 34 of Set 6 | margate
# Processing Record 35 of Set 6 | glace bay
# Processing Record 36 of Set 6 | chardara
# Processing Record 37 of Set 6 | boudjima
# Processing Record 38 of Set 6 | fort-shevchenko
# Processing Record 39 of Set 6 | amlame
# Processing Record 40 of Set 6 | ratnagiri
# Processing Record 41 of Set 6 | vetlanda
# Processing Record 42 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 43 of Set 6 | kingscliff
# Processing Record 44 of Set 6 | tura
# Processing Record 45 of Set 6 | ondjiva
# Processing Record 46 of Set 6 | meadow lake
# Processing Record 47 of Set 6 | menongue
# Processing Record 48 of Set 6 | tofol
# Processing Record 49 of Set 6 | kapoeta
# Processing Record 0 of Set 7 | kralendijk
# Processing Record 1 of Set 7 | plettenberg bay
# Processing Record 2 of Set 7 | novyy urgal
# Processing Record 3 of Set 7 | ostrovskoye
# Processing Record 4 of Set 7 | bairnsdale
# Processing Record 5 of Set 7 | faya-largeau
# Processing Record 6 of Set 7 | oruro
# Processing Record 7 of Set 7 | kiunga
# Processing Record 8 of Set 7 | enewetak
# Processing Record 9 of Set 7 | xilin hot
# Processing Record 10 of Set 7 | escanaba
# Processing Record 11 of Set 7 | aras-asan
# Processing Record 12 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 13 of Set 7 | sechura
# Processing Record 14 of Set 7 | kavaratti
# Processing Record 15 of Set 7 | st. john's
# Processing Record 16 of Set 7 | sault ste. marie
# Processing Record 17 of Set 7 | taksimo
# Processing Record 18 of Set 7 | kutum
# Processing Record 19 of Set 7 | alesund
# Processing Record 20 of Set 7 | choele choel
# Processing Record 21 of Set 7 | axim
# Processing Record 22 of Set 7 | blythe
# Processing Record 23 of Set 7 | carlos a. carrillo
# Processing Record 24 of Set 7 | cadillac
# Processing Record 25 of Set 7 | mozarlandia
# Processing Record 26 of Set 7 | isiro
# Processing Record 27 of Set 7 | hiratacho
# Processing Record 28 of Set 7 | cochirleanca
# Processing Record 29 of Set 7 | queenstown
# Processing Record 30 of Set 7 | hargeysa
# Processing Record 31 of Set 7 | la ronge
# Processing Record 32 of Set 7 | sarina
# Processing Record 33 of Set 7 | baihe
# Processing Record 34 of Set 7 | puerto baquerizo moreno
# Processing Record 35 of Set 7 | dakhla
# Processing Record 36 of Set 7 | tluszcz
# Processing Record 37 of Set 7 | floro
# Processing Record 38 of Set 7 | sterling
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | popondetta
# Processing Record 41 of Set 7 | qulsary
# Processing Record 42 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 43 of Set 7 | kotamangalam
# Processing Record 44 of Set 7 | andovoranto
# Processing Record 45 of Set 7 | zabol
# Processing Record 46 of Set 7 | tucumcari
# Processing Record 47 of Set 7 | crucecita
# Processing Record 48 of Set 7 | tromso
# Processing Record 49 of Set 7 | huarmey
# Processing Record 0 of Set 8 | nikolayevsk-on-amure
# Processing Record 1 of Set 8 | antsiranana
# Processing Record 2 of Set 8 | visegrad
# Processing Record 3 of Set 8 | kyshtovka
# Processing Record 4 of Set 8 | naze
# Processing Record 5 of Set 8 | les cayes
# Processing Record 6 of Set 8 | hun
# Processing Record 7 of Set 8 | khmilnyk
# Processing Record 8 of Set 8 | qarazhal
# Processing Record 9 of Set 8 | galdar
# Processing Record 10 of Set 8 | labytnangi
# Processing Record 11 of Set 8 | kapuskasing
# Processing Record 12 of Set 8 | carahue
# Processing Record 13 of Set 8 | las heras
# Processing Record 14 of Set 8 | abadan
# Processing Record 15 of Set 8 | tucurui
# Processing Record 16 of Set 8 | wick
# Processing Record 17 of Set 8 | villa angela
# Processing Record 18 of Set 8 | thunder bay
# Processing Record 19 of Set 8 | baishishan
# Processing Record 20 of Set 8 | concepcion
# Processing Record 21 of Set 8 | ghat
# Processing Record 22 of Set 8 | smithers
# Processing Record 23 of Set 8 | praia da vitoria
# Processing Record 24 of Set 8 | phan rang-thap cham
# Processing Record 25 of Set 8 | antonio enes
# Processing Record 26 of Set 8 | hanzhong
# Processing Record 27 of Set 8 | ballina
# Processing Record 28 of Set 8 | shanghai
# Processing Record 29 of Set 8 | kayyerkan
# Processing Record 30 of Set 8 | nouadhibou
# Processing Record 31 of Set 8 | sisimiut
# Processing Record 32 of Set 8 | chonchi
# Processing Record 33 of Set 8 | kolonia town
# Processing Record 34 of Set 8 | iguape
# Processing Record 35 of Set 8 | souillac
# Processing Record 36 of Set 8 | sinabang
# Processing Record 37 of Set 8 | bengkulu
# Processing Record 38 of Set 8 | ulladulla
# Processing Record 39 of Set 8 | rusk
# Processing Record 40 of Set 8 | susuman
# Processing Record 41 of Set 8 | savnik
# City not found. Skipping...
# Processing Record 42 of Set 8 | casablanca
# Processing Record 43 of Set 8 | qurayyat
# Processing Record 44 of Set 8 | chifeng
# Processing Record 45 of Set 8 | bac lieu
# Processing Record 46 of Set 8 | goondiwindi
# Processing Record 47 of Set 8 | pemangkat
# Processing Record 48 of Set 8 | peniche
# Processing Record 49 of Set 8 | at taj
# Processing Record 0 of Set 9 | isangel
# Processing Record 1 of Set 9 | nogliki
# Processing Record 2 of Set 9 | kharabali
# Processing Record 3 of Set 9 | illizi
# Processing Record 4 of Set 9 | rawah
# Processing Record 5 of Set 9 | homer
# Processing Record 6 of Set 9 | ciudad general teran
# Processing Record 7 of Set 9 | imperatriz
# Processing Record 8 of Set 9 | mccook
# Processing Record 9 of Set 9 | barcelos
# Processing Record 10 of Set 9 | new norfolk
# Processing Record 11 of Set 9 | n'zeto
# Processing Record 12 of Set 9 | gadzhiyevo
# Processing Record 13 of Set 9 | salinopolis
# Processing Record 14 of Set 9 | fortuna
# Processing Record 15 of Set 9 | koryukivka
# Processing Record 16 of Set 9 | kristiansund
# Processing Record 17 of Set 9 | prieska
# Processing Record 18 of Set 9 | sitka
# Processing Record 19 of Set 9 | lata
# Processing Record 20 of Set 9 | satuek
# Processing Record 21 of Set 9 | kashgar
# Processing Record 22 of Set 9 | brookings
# Processing Record 23 of Set 9 | benjamin constant
# Processing Record 24 of Set 9 | soio
# Processing Record 25 of Set 9 | santa rosa de rio primero
# Processing Record 26 of Set 9 | saint-philippe
# Processing Record 27 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 28 of Set 9 | farmville
# Processing Record 29 of Set 9 | byron bay
# Processing Record 30 of Set 9 | acarau
# Processing Record 31 of Set 9 | hami
# Processing Record 32 of Set 9 | vuktyl
# Processing Record 33 of Set 9 | hazro
# Processing Record 34 of Set 9 | birao
# Processing Record 35 of Set 9 | daru
# Processing Record 36 of Set 9 | thames
# Processing Record 37 of Set 9 | oberding
# Processing Record 38 of Set 9 | bardai
# Processing Record 39 of Set 9 | pulsano
# Processing Record 40 of Set 9 | bagan
# Processing Record 41 of Set 9 | qarauyl
# Processing Record 42 of Set 9 | pontes e lacerda
# Processing Record 43 of Set 9 | maebaru-chuo
# Processing Record 44 of Set 9 | sydney mines
# Processing Record 45 of Set 9 | mugia
# Processing Record 46 of Set 9 | vershino-darasunskiy
# Processing Record 47 of Set 9 | ain taya
# Processing Record 48 of Set 9 | salinas
# Processing Record 49 of Set 9 | shingu
# Processing Record 0 of Set 10 | al kharj
# Processing Record 1 of Set 10 | necochea
# Processing Record 2 of Set 10 | taoudenni
# Processing Record 3 of Set 10 | hamlyn heights
# Processing Record 4 of Set 10 | valentin gomez farias
# Processing Record 5 of Set 10 | carbonear
# Processing Record 6 of Set 10 | nyurba
# Processing Record 7 of Set 10 | cascais
# Processing Record 8 of Set 10 | aripuana
# Processing Record 9 of Set 10 | ratchaburi
# Processing Record 10 of Set 10 | lakatoro
# Processing Record 11 of Set 10 | kedrovyy
# Processing Record 12 of Set 10 | nova sintra
# Processing Record 13 of Set 10 | ferkessedougou
# Processing Record 14 of Set 10 | pul-e khumri
# Processing Record 15 of Set 10 | nanao
# Processing Record 16 of Set 10 | castillos
# Processing Record 17 of Set 10 | madera
# Processing Record 18 of Set 10 | 'amran
# City not found. Skipping...
# Processing Record 19 of Set 10 | nizao
# Processing Record 20 of Set 10 | panaba
# Processing Record 21 of Set 10 | katabu
# Processing Record 22 of Set 10 | mawlamyinegyunn
# Processing Record 23 of Set 10 | machico
# Processing Record 24 of Set 10 | skiathos
# Processing Record 25 of Set 10 | nizhnesortymskiy
# Processing Record 26 of Set 10 | urangan
# Processing Record 27 of Set 10 | walvis bay
# Processing Record 28 of Set 10 | cururupu
# Processing Record 29 of Set 10 | baillif
# Processing Record 30 of Set 10 | oranjemund
# Processing Record 31 of Set 10 | yashkul'
# Processing Record 32 of Set 10 | hammerfest
# Processing Record 33 of Set 10 | shibirghan
# Processing Record 34 of Set 10 | stanwood
# Processing Record 35 of Set 10 | kavala
# Processing Record 36 of Set 10 | minas de marcona
# Processing Record 37 of Set 10 | chibougamau
# Processing Record 38 of Set 10 | tahe
# Processing Record 39 of Set 10 | pathein
# Processing Record 40 of Set 10 | ibirama
# Processing Record 41 of Set 10 | san andres
# Processing Record 42 of Set 10 | trinidad
# Processing Record 43 of Set 10 | stephenville
# Processing Record 44 of Set 10 | inderbor
# Processing Record 45 of Set 10 | bang saphan
# Processing Record 46 of Set 10 | mantua
# Processing Record 47 of Set 10 | al kharijah
# Processing Record 48 of Set 10 | randfontein
# Processing Record 49 of Set 10 | mamuju
# Processing Record 0 of Set 11 | nadi
# Processing Record 1 of Set 11 | sumbawa besar
# Processing Record 2 of Set 11 | porto novo
# Processing Record 3 of Set 11 | nelson bay
# Processing Record 4 of Set 11 | yeraliyev
# Processing Record 5 of Set 11 | sao felix do xingu
# Processing Record 6 of Set 11 | acapulco de juarez
# Processing Record 7 of Set 11 | dalgopol
# Processing Record 8 of Set 11 | northam
# Processing Record 9 of Set 11 | buraydah
# Processing Record 10 of Set 11 | lagoa
# Processing Record 11 of Set 11 | imbituba
# Processing Record 12 of Set 11 | kuantan
# Processing Record 13 of Set 11 | cidade velha
# Processing Record 14 of Set 11 | tobelo
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | kirovskiy
# Processing Record 17 of Set 11 | abeche
# Processing Record 18 of Set 11 | ponta delgada
# Processing Record 19 of Set 11 | monrovia
# Processing Record 20 of Set 11 | takanosu
# Processing Record 21 of Set 11 | gizo
# Processing Record 22 of Set 11 | labrador city
# Processing Record 23 of Set 11 | lembar
# City not found. Skipping...
# Processing Record 24 of Set 11 | cotonou
# Processing Record 25 of Set 11 | mata-utu
# Processing Record 26 of Set 11 | voi
# Processing Record 27 of Set 11 | fort bragg
# Processing Record 28 of Set 11 | calca
# Processing Record 29 of Set 11 | luanda
# Processing Record 30 of Set 11 | gelemso
# Processing Record 31 of Set 11 | frankenmuth
# Processing Record 32 of Set 11 | timmins
# Processing Record 33 of Set 11 | salvacion
# Processing Record 34 of Set 11 | kill devil hills
# Processing Record 35 of Set 11 | usogorsk
# Processing Record 36 of Set 11 | coquimbo
# Processing Record 37 of Set 11 | margherita
# Processing Record 38 of Set 11 | ankang
# Processing Record 39 of Set 11 | polyarnyy
# Processing Record 40 of Set 11 | valley east
# City not found. Skipping...
# Processing Record 41 of Set 11 | pangai
# Processing Record 42 of Set 11 | nuku'alofa
# Processing Record 43 of Set 11 | callao
# Processing Record 44 of Set 11 | dalbandin
# Processing Record 45 of Set 11 | costa calma
# City not found. Skipping...
# Processing Record 46 of Set 11 | comandante fontana
# Processing Record 47 of Set 11 | gondar
# Processing Record 48 of Set 11 | quito
# Processing Record 49 of Set 11 | chust
# Processing Record 0 of Set 12 | palm valley
# Processing Record 1 of Set 12 | akureyri
# Processing Record 2 of Set 12 | baganga
# Processing Record 3 of Set 12 | ust'-ilimsk
# Processing Record 4 of Set 12 | berdigestyakh
# Processing Record 5 of Set 12 | santa ana
# Processing Record 6 of Set 12 | pangody
# Processing Record 7 of Set 12 | nkurenkuru
# City not found. Skipping...
# Processing Record 8 of Set 12 | ilomantsi
# Processing Record 9 of Set 12 | trairi
# Processing Record 10 of Set 12 | quilmana
# Processing Record 11 of Set 12 | nieuw amsterdam
# Processing Record 12 of Set 12 | mochudi
# Processing Record 13 of Set 12 | san patricio
# Processing Record 14 of Set 12 | zakynthos
# Processing Record 15 of Set 12 | lokhvytsya
# Processing Record 16 of Set 12 | creston
# Processing Record 17 of Set 12 | vorkuta
# Processing Record 18 of Set 12 | sosnogorsk
# Processing Record 19 of Set 12 | namibe
# Processing Record 20 of Set 12 | qasr-e qand
# City not found. Skipping...
# Processing Record 21 of Set 12 | brokopondo
# Processing Record 22 of Set 12 | kawthoung
# City not found. Skipping...
# Processing Record 23 of Set 12 | kilmore
# Processing Record 24 of Set 12 | xucheng
# Processing Record 25 of Set 12 | kuchinda
# Processing Record 26 of Set 12 | kirensk
# Processing Record 27 of Set 12 | al artawiyah
# Processing Record 28 of Set 12 | sale
# Processing Record 29 of Set 12 | lucaya
# Processing Record 30 of Set 12 | nadym
# Processing Record 31 of Set 12 | sadovoye
# Processing Record 32 of Set 12 | hengyang
# Processing Record 33 of Set 12 | rabak
# Processing Record 34 of Set 12 | malango
# Processing Record 35 of Set 12 | ventspils
# Processing Record 36 of Set 12 | bamboo flat
# Processing Record 37 of Set 12 | sos'va
# Processing Record 38 of Set 12 | cooma
# Processing Record 39 of Set 12 | kati
# Processing Record 40 of Set 12 | nguigmi
# Processing Record 41 of Set 12 | qal'at bishah
# City not found. Skipping...
# Processing Record 42 of Set 12 | santa cruz
# Processing Record 43 of Set 12 | nagqu
# Processing Record 44 of Set 12 | cill airne
# Processing Record 45 of Set 12 | vila velha
# Processing Record 46 of Set 12 | carolina beach
# Processing Record 47 of Set 12 | buka
# Processing Record 48 of Set 12 | la'ie
# Processing Record 49 of Set 12 | tirumullaivasal
# Processing Record 0 of Set 13 | kondopoga
# Processing Record 1 of Set 13 | enriquillo
# Processing Record 2 of Set 13 | nizhniy kuranakh
# Processing Record 3 of Set 13 | seydi
# Processing Record 4 of Set 13 | karratha
# Processing Record 5 of Set 13 | rawlins
# Processing Record 6 of Set 13 | puerto quijarro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0  edinburgh of the seven seas -37.0676  -12.3116     18.41        71
# 1                      pizarro   4.9533  -77.3660     28.77        71
# 2               margaret river -33.9500  115.0667     21.67        46
# 3                         jaru -10.4389  -62.4664     29.72        72
# 4                     sylt-ost  54.8833    8.3500      3.05        81
#
#    Cloudiness  Wind Speed Country        Date
# 0          90        5.40      SH  1707406926
# 1          66        1.00      CO  1707406927
# 2           0        5.14      AU  1707406928
# 3         100        1.52      BR  1707406652
# 4         100        1.54      DE  1707406929

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116     18.41        71
# 1                            pizarro   4.9533  -77.3660     28.77        71
# 2                     margaret river -33.9500  115.0667     21.67        46
# 3                               jaru -10.4389  -62.4664     29.72        72
# 4                           sylt-ost  54.8833    8.3500      3.05        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                90        5.40      SH  1707406926
# 1                66        1.00      CO  1707406927
# 2                 0        5.14      AU  1707406928
# 3               100        1.52      BR  1707406652
# 4               100        1.54      DE  1707406929

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# # Build scatter plot for latitude vs. temperature
import datetime
import matplotlib.pyplot as plt


plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], alpha=0.5, edgecolors='black')

# Format date
date = datetime.datetime.now()
date_str = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)
plt.title(f"City Max Latitude vs. Temperature ({date_str})")  
plt.tight_layout()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], alpha = 0.5, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Humidity ({date_str})") 
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df ['Lat'], city_data_df['Humidity'], alpha = 0.5, edgecolors ='black')

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title(f"City Max Latitude vs. Cloudiness ({date_str})") 
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid("Ture")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], alpha = 0.5, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. WindSpeed ({date_str})") 
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (%)')
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(x, y, xlabel='', ylabel='', title=''):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.text(0.5, 0.9, line_eq, fontsize=12, ha='center', transform=plt.gca().transAxes, color='red')

    regress_values = x * slope + intercept
    
    # Plot scatter plot
    plt.scatter(x, y)

    # Plot regression line
    plt.plot(x, slope*x + intercept, color='red')

    # Add labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # print the r value
    print(f'The r-value is: {r_value**2}')
    
    # Show plot
    plt.show()

# # Define a function to create Linear Regression plots
# def linear_regression_plot(x, y, xlabel='', ylabel='', title=''):
#     slope, intercept, r_value, p_value, std_err = linregress(x, y)
#     line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#     plt.text(0.5, 0.9, line_eq, fontsize=12, ha='center', transform=plt.gca().transAxes, color='red')

#     regress_values = x * slope + intercept
#      # Plot scatter plot
#     plt.scatter(x, y)

#     # Plot regression line
#     plt.plot(x, slope*x + intercept, color='red')


#     # Add labels and title
#     plt.xlabel(xlabel)
#     plt.ylabel(ylabel)
    
#     # print the r value
#     print(f'The r-value is: {r_value**2}')
#     # Show plot
#     plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                       pizarro   4.9533  -77.3660     28.77        71
# 4                      sylt-ost  54.8833    8.3500      3.05        81
# 6                      qaqortoq  60.7167  -46.0333     -9.57        67
# 8        hawaiian paradise park  19.5933 -154.9731     18.35        91
# 9                        pandan  14.0453  124.1694     24.49        87
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                66        1.00      CO  1707406927
# 4               100        1.54      DE  1707406929
# 6                23        6.33      GL  1707406930
# 8                 0        2.57      US  1707406828
# 9                 2        1.77      PH  1707406932

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]


# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676  -12.3116     18.41        71
# 2                     margaret river -33.9500  115.0667     21.67        46
# 3                               jaru -10.4389  -62.4664     29.72        72
# 5                           kerikeri -35.2268  173.9474     16.62        89
# 7                       puerto ayora  -0.7393  -90.3518     28.98        90
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                90        5.40      SH  1707406926
# 2                 0        5.14      AU  1707406928
# 3               100        1.52      BR  1707406652
# 5                49        2.31      NZ  1707406929
# 7                90        2.68      EC  1707406931

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
#linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Max Temp')
# Scatter plot for latitude vs. maximum temperature in the Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], alpha=0.5, edgecolors='black')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], intercept + slope * northern_hemi_df['Lat'], 'r', label='fitted line')

# Add the equation of the line to the plot
plt.text(0, northern_hemi_df['Max Temp'].max(), f'y = {slope:.2f}x + {intercept:.2f}', color='red')

plt.grid(True)
plt.title("Northern Hemisphere Max Latitude vs. Temperature")
plt.tight_layout()
plt.legend()

# Show plot
plt.show()

# Print the r-value
print(f'The r-value is: {r_value**2}')
# Out:
# The r-value is: 0.7714470505916879

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temp')
# Out:
# The r-value is: 0.3391867781799962

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.2265449410689458

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.02581873960349083

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-value is: 0.06478013551060799

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-value is: 0.03758393594132181

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-value is: 0.028016403117682234

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-value is: 0.028016403117682234

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
